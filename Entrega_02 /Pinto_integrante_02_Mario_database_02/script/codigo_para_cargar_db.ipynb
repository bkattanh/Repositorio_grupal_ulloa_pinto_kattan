# %%
import pandas as pd

# Cargar datos con codificación compatible y separador ";"
df = pd.read_csv("/content/drive/MyDrive/Base de datos Mario Pinto.csv",
                 sep=",",
                 encoding="latin-1")

# Echar un vistazo
df.head(112)
# Out:
#              Categoria                Prueba    Marca     Año  \
# 0     Adulto Masculino                  800m  1.48.36  2019.0
# 1     Adulto Masculino                  800m  1.57.97  2019.0
# 2      Adulto Femenino                  800m  2.10.48  2019.0
# 3     Adulto Masculino  Lanzamiento Jabalina    75.97  2019.0
# 4      Adulto Femenino  Lanzamiento Jabalina    49.16  2019.0
# ..                 ...                   ...      ...     ...
# 107   Juvenil Femenino      Lanzamiento Bala    13.29  2021.0
# 108   Juvenil Femenino      Lanzamiento Bala    13.12  2021.0
# 109  Juvenil Masculino      Lanzamiento Bala    16.18  2021.0
# 110  Juvenil Masculino  Lanzamiento Jabalina    65.52  2021.0
# 111                NaN                   NaN      NaN     NaN
#
#               Competencia      Nombre Atleta  Unnamed: 6
# 0     Sudamericano Adulto  Alejandro Peirano         NaN
# 1     Sudamericano Adulto       Rafael Muñoz         NaN
# ...
